# %% [markdown]
# ## loader.py

# %%
from loader import load_dataset

# %%
dataset = load_dataset()
# Out:
# Loaded 500 segments.

# %% [markdown]
# ##### Some sanity checks

# %%
# Tests to check data is loaded correctly
assert isinstance(dataset, list), "dataset should be a list"

assert len(dataset) > 0, "dataset should not be empty"

for item in dataset:
    assert isinstance(item, dict), "Each item should be a dict"
    for key in ["signal", "label", "set_name", "segment_id"]:
        assert key in item, f"Missing key: {key}"
    assert hasattr(item["signal"], "shape"), "signal should be a numpy array"

# %%
# Check how many segments are in each folder
from collections import Counter
folder_counts = Counter([item['set_name'] for item in dataset])
print('Segments per folder:', folder_counts)

# Check how many segments are in the overall dataset
print('Total segments:', len(dataset))

# Show a few sample segments and their shapes
print('Segment samples:')
print(dataset[0])
print(dataset[105]['signal'])
print(dataset[105]['signal'].shape)
# Out:
# Segments per folder: Counter({'F': 100, 'N': 100, 'O': 100, 'S': 100, 'Z': 100})
# Total segments: 500
# Segment samples:
# {'signal': array([34., 33., 28., ..., 39., 41.,  7.], shape=(4097,)), 'label': 0, 'set_name': 'F', 'segment_id': 'F001'}
# [-148. -155. -156. ...  -81.  -77.   95.]
# (4097,)

# %% [markdown]
# ## windows.py

# %%
from windows import segment_windows

# %%
segment = dataset[0]
segment_windows = segment_windows(segment, 10, 2)
print(segment_windows)
# Out:
# [(array([34., 33., 28., 22., 21., 22., 22., 19., 22., 18.]), 0), (array([28., 22., 21., 22., 22., 19., 22., 18., 22., 25.]), 0), (array([21., 22., 22., 19., 22., 18., 22., 25., 15.,  5.]), 0), (array([22., 19., 22., 18., 22., 25., 15.,  5.,  0., -8.]), 0), (array([ 22.,  18.,  22.,  25.,  15.,   5.,   0.,  -8., -10., -19.]), 0), (array([ 22.,  25.,  15.,   5.,   0.,  -8., -10., -19., -25., -39.]), 0), (array([ 15.,   5.,   0.,  -8., -10., -19., -25., -39., -49., -50.]), 0), (array([  0.,  -8., -10., -19., -25., -39., -49., -50., -54., -54.]), 0), (array([-10., -19., -25., -39., -49., -50., -54., -54., -59., -63.]), 0), (array([-25., -39., -49., -50., -54., -54., -59., -63., -64., -58.]), 0), (array([-49., -50., -54., -54., -59., -63., -64., -58., -53., -39.]), 0), (array([-54., -54., -59., -63., -64., -58., -53., -39., -43., -37.]), 0), (array([-59., -63., -64., -58., -53., -39., -43., -37., -32., -24.]), 0), (array([-64., -58., -53., -39., -43., -37., -32., -24., -14.,  -1.]), 0), (array([-53., -39., -43., -37., -32., -24., -14.,  -1.,  12.,  18.]), 0), (array([-43., -37., -32., -24., -14.,  -1.,  12.,  18.,  24.,  23.]), 0), (array([-32., -24., -14.,  -1.,  12.,  18.,  24.,  23.,  24.,  25.]), 0), (array([-14.,  -1.,  12.,  18.,  24.,  23.,  24.,  25.,  27.,  29.]), 0), (array([12., 18., 24., 23., 24., 25., 27., 29., 28., 34.]), 0), (array([24., 23., 24., 25., 27., 29., 28., 34., 44., 57.]), 0), (array([24., 25., 27., 29., 28., 34., 44., 57., 64., 80.]), 0), (array([27., 29., 28., 34., 44., 57., 64., 80., 83., 86.]), 0), (array([28., 34., 44., 57., 64., 80., 83., 86., 76., 60.]), 0), (array([44., 57., 64., 80., 83., 86., 76., 60., 47., 40.]), 0), (array([64., 80., 83., 86., 76., 60., 47., 40., 42., 42.]), 0), (array([83., 86., 76., 60., 47., 40., 42., 42., 49., 61.]), 0), (array([76., 60., 47., 40., 42., 42., 49., 61., 68., 71.]), 0), (array([47., 40., 42., 42., 49., 61., 68., 71., 74., 74.]), 0), (array([42., 42., 49., 61., 68., 71., 74., 74., 79., 69.]), 0), (array([49., 61., 68., 71., 74., 74., 79., 69., 58., 50.]), 0), (array([68., 71., 74., 74., 79., 69., 58., 50., 51., 48.]), 0), (array([74., 74., 79., 69., 58., 50., 51., 48., 51., 51.]), 0), (array([79., 69., 58., 50., 51., 48., 51., 51., 41., 40.]), 0), (array([58., 50., 51., 48., 51., 51., 41., 40., 37., 42.]), 0), (array([51., 48., 51., 51., 41., 40., 37., 42., 40., 46.]), 0), (array([51., 51., 41., 40., 37., 42., 40., 46., 44., 51.]), 0), (array([41., 40., 37., 42., 40., 46., 44., 51., 42., 45.]), 0), (array([37., 42., 40., 46., 44., 51., 42., 45., 47., 56.]), 0), (array([40., 46., 44., 51., 42., 45., 47., 56., 66., 64.]), 0), (array([44., 51., 42., 45., 47., 56., 66., 64., 61., 63.]), 0), (array([42., 45., 47., 56., 66., 64., 61., 63., 72., 81.]), 0), (array([47., 56., 66., 64., 61., 63., 72., 81., 82., 85.]), 0), (array([66., 64., 61., 63., 72., 81., 82., 85., 88., 94.]), 0), (array([61., 63., 72., 81., 82., 85., 88., 94., 97., 95.]), 0), (array([72., 81., 82., 85., 88., 94., 97., 95., 93., 86.]), 0), (array([82., 85., 88., 94., 97., 95., 93., 86., 82., 69.]), 0), (array([88., 94., 97., 95., 93., 86., 82., 69., 46., 30.]), 0), (array([97., 95., 93., 86., 82., 69., 46., 30., 11., -2.]), 0), (array([ 93.,  86.,  82.,  69.,  46.,  30.,  11.,  -2., -13., -11.]), 0), (array([ 82.,  69.,  46.,  30.,  11.,  -2., -13., -11., -12.,  -8.]), 0), (array([ 46.,  30.,  11.,  -2., -13., -11., -12.,  -8.,  -2.,   2.]), 0), (array([ 11.,  -2., -13., -11., -12.,  -8.,  -2.,   2.,   6.,  13.]), 0), (array([-13., -11., -12.,  -8.,  -2.,   2.,   6.,  13.,  19.,  23.]), 0), (array([-12.,  -8.,  -2.,   2.,   6.,  13.,  19.,  23.,  24.,  24.]), 0), (array([-2.,  2.,  6., 13., 19., 23., 24., 24., 30., 34.]), 0), (array([ 6., 13., 19., 23., 24., 24., 30., 34., 43., 56.]), 0), (array([19., 23., 24., 24., 30., 34., 43., 56., 61., 63.]), 0), (array([24., 24., 30., 34., 43., 56., 61., 63., 57., 49.]), 0), (array([30., 34., 43., 56., 61., 63., 57., 49., 35., 17.]), 0), (array([43., 56., 61.,  ...
